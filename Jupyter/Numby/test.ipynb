# %% [markdown]
# # Testing new methods

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x= [21, 22, 23, 4, 5, 6, 77, 8, 9, 10, 31, 32, 33, 34, 35, 36, 37,
       18, 49, 50, 100]

# %%
num_bins = 5

# %%
plt.hist(x, num_bins)
plt.show()

# %%
thresholds = np.linspace(2.0, 3.0, num=5)
thresholds
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %%
N = 8

np.linspace(0, 10, N, endpoint=True)
# Out:
# array([ 0.        ,  1.42857143,  2.85714286,  4.28571429,  5.71428571,
#         7.14285714,  8.57142857, 10.        ])

# %%
import matplotlib.pyplot as plt
N = 8
y = np.zeros(N)
x1 = np.linspace(0, 10, N, endpoint=True)
x2 = np.linspace(0, 10, N, endpoint=False)
plt.plot(x1, y, 'o')
plt.plot(x2, y + 0.5, 'o')
plt.ylim([-0.5, 1])
plt.show()
